# %% [markdown]
# <font size="5">   <center> Linear Regression</center>
# <br>
# <center>by</center>
# &emsp;&emsp;&emsp;&emsp;
#
# <font size="5">    <center>Ramesh Kestur, IIIT-B</center>
# <br>
# <center><font size="3"> Public profile</center>
# <br>
# <center><a href="https://www.linkedin.com/in/rameshkestur/" target="_blank">Linked In</a></center>
# <br>
# <center><a href="https://www.researchgate.net/profile/Ramesh_Kestur" target="_blank">Research Gate</a></center>
# <br>
# <center><a href="https://scholar.google.co.in/citations?user=P28Shk8AAAAJ&hl=en" target="_blank">Google Scholar</a></center>

# %% [markdown]
# <font size="5">  Learning Objectives
# <font size="3">
# * Considerations for selecting Linear Regression as an approach to solving a real world problem
# * Assumptions of Linear regression
# * Key methods for Feature engineering
# * Model development
# * Evaluation of model - Goodness of fit

# %% [markdown]
# <center><font size="5"> Table of Contents</center>

# %% [markdown]
# 1. Problem Description
# 2. Approach to Problem Resolution
# 3. EDA
# 4. Feature Engineering/Data Preparation
# 5. Model Development
# 6. Analysis of results

# %% [markdown]
# # Problem Statement
#
# A real estate company  has a dataset containing the prices of properties in a certain region. It wishes to use the data to optimise the sale prices of the properties based on important factors such as area, bedrooms, parking, etc.
#
# Essentially, the company wants —
#
# * To identify the variables affecting house prices, e.g. area, number of rooms, bathrooms, etc.
#
# * To create a linear model that quantitatively relates house prices with variables such as number of rooms, area, number of bathrooms, etc.
#
# * To know the accuracy of the model, i.e. how well these variables can predict house prices.
#
# <a href="https://www.kaggle.com/ashydv/housing-dataset" target="_blank">Housing dataset</a>

# %% [markdown]
# # Approach to Problem Resolution
#
# Data considerations for choice of model and problem formulation
# * It is a structured data set
# * One variable needs to be predicted
# * There are several other variables which influence predicted variable and they are independent of each other.
# <br>
# <br>
# With this premise, the given problem can be formulated as a linear regression problem

# %% [markdown]
# Importing libraries and review of data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm  
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn import preprocessing
from sklearn import model_selection

# %% [markdown]
# Load appropriate dataset and verify if loading is correct.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
housing=pd.read_csv("Housing.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the dataset
# ----> 2 housing=pd.read_csv("Housing.csv")
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# Set the number of rows and columns to be displayed

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Exploratory Data Analytics is an  important step towards understanding the data.It is useful in identifying multicollinearity, the scale and range of data, the underlying distribution of data etc.

# %%
# View the header and the top 5 fields

housing.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0  13300000   7420         4          2        3      yes        no       no              no             yes        2      yes        furnished
# 1  12250000   8960         4          4        4      yes        no       no              no             yes        3       no        furnished
# 2  12250000   9960         3          2        2      yes        no      yes              no              no        2      yes   semi-furnished
# 3  12215000   7500         4          2        2      yes        no      yes              no             yes        3      yes        furnished
# 4  11410000   7420         4          1        2      yes       yes      yes              no             yes        2       no        furnished
# ...

# %% [markdown]
# It can be observed that there are categorical fields such as main road, guest room airconditioning and furnishing status

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# There are 545 entries and 13 variables. The predicted/dependent variable is price and the remaining 12 are predictor/independent variables

# %%
housing.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories     parking
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505    0.693578
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492    0.861586
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000    0.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000    0.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000    0.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000    1.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000    3.000000

# %% [markdown]
# The range of variables: Price has a high range of values followed by area of the house. The other variables are in the single digit range.

# %%
housing
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0    13300000  7420         4          2        3      yes        no       no              no             yes        2      yes        furnished
# 1    12250000  8960         4          4        4      yes        no       no              no             yes        3       no        furnished
# 2    12250000  9960         3          2        2      yes        no      yes              no              no        2      yes   semi-furnished
# 3    12215000  7500         4          2        2      yes        no      yes              no             yes        3      yes        furnished
# 4    11410000  7420         4          1        2      yes       yes      yes              no             yes        2       no        furnished
# ...

# %%
print(housing)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0    13300000  7420         4          2        3      yes        no       no              no             yes        2      yes        furnished
# 1    12250000  8960         4          4        4      yes        no       no              no             yes        3       no        furnished
# 2    12250000  9960         3          2        2      yes        no      yes              no              no        2      yes   semi-furnished
# 3    12215000  7500         4          2        2      yes        no      yes              no             yes        3      yes        furnished
# 4    11410000  7420         4          1        2      yes       yes      yes              no             yes        2       no        furnished
# ...

# %%
housing.shape
# Out:
# (545, 13)

# %%
housing.shape[0]
# Out:
# 545

# %%
housing.shape[1]
# Out:
# 13

# %% [markdown]
# Let us check for null values. Compute the percentage of null values for every field

# %%
housing.isnull().sum()*100/housing.shape[0]
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %% [markdown]
# There are no null values. Saves us the effort in eliminating null values!

# %% [markdown]
# A box plot provides a good visualization of the univariate data.  A description of the interpretation of box plot can be found
#
# <a href="https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots" target="_blank">Here</a>

# %%
# Outlier Analysis
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(housing['price'], ax = axs[0,0])
plt2 = sns.boxplot(housing['area'], ax = axs[0,1])
plt3 = sns.boxplot(housing['bedrooms'], ax = axs[0,2])
plt1 = sns.boxplot(housing['bathrooms'], ax = axs[1,0])
plt2 = sns.boxplot(housing['stories'], ax = axs[1,1])
plt3 = sns.boxplot(housing['parking'], ax = axs[1,2])

plt.tight_layout()

# %% [markdown]
# It can be observed that Price and Area have higher number of outliers

# %% [markdown]
# A pair plot provides a grid of scatter plots between each one of the variables

# %%
sns.pairplot(housing)
plt.show()

# %% [markdown]
# A corellation heat map is useful to visualize multicollinearity

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(housing.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# It can be observed that there is no multicollinearity among any of the variables

# %% [markdown]
# A distplot plot is a univariate distribution of observations. Distplot provides a combination of histogram and kde plot

# %%
sns.distplot(housing['price'])
plt.xlabel("price")
plt.ylabel("")
plt.show()

# %%
sns.distplot(housing['area'])
plt.xlabel("Area")
plt.ylabel("")
plt.show()

# %% [markdown]
# Other box plot views. sns.box plot provides an elegant 'hue' option

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'mainroad', y = 'price', data = housing)
plt.subplot(2,3,2)
sns.boxplot(x = 'guestroom', y = 'price', data = housing)
plt.subplot(2,3,3)
sns.boxplot(x = 'basement', y = 'price', data = housing)
plt.subplot(2,3,4)
sns.boxplot(x = 'hotwaterheating', y = 'price', data = housing)
plt.subplot(2,3,5)
sns.boxplot(x = 'airconditioning', y = 'price', data = housing)
plt.subplot(2,3,6)
sns.boxplot(x = 'furnishingstatus', y = 'price', data = housing)
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'furnishingstatus', y = 'price', hue = 'airconditioning', data = housing)
plt.show()

# %% [markdown]
# # Data Preparation/Feature engineering

# %% [markdown]
# ## Outlier Treatment

# %% [markdown]
# Box plots are useful in identyfying outliers. For an understanding of interpreting box plots check
#
# <a href="https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots" target="_blank">here</a>

# %%
# outlier treatment for price
plt.boxplot(housing.price)
Q1 = housing.price.quantile(0.25)
Q3 = housing.price.quantile(0.75)
IQR = Q3 - Q1
housing = housing[(housing.price >= Q1 - 1.5*IQR) & (housing.price <= Q3 + 1.5*IQR)]

# %%
# outlier treatment for area
plt.boxplot(housing.area)
Q1 = housing.area.quantile(0.25)
Q3 = housing.area.quantile(0.75)
IQR = Q3 - Q1
housing = housing[(housing.area >= Q1 - 1.5*IQR) & (housing.area <= Q3 + 1.5*IQR)]

# %%
# Outlier Analysis
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(housing['price'], ax = axs[0,0])
plt2 = sns.boxplot(housing['area'], ax = axs[0,1])
plt3 = sns.boxplot(housing['bedrooms'], ax = axs[0,2])
plt1 = sns.boxplot(housing['bathrooms'], ax = axs[1,0])
plt2 = sns.boxplot(housing['stories'], ax = axs[1,1])
plt3 = sns.boxplot(housing['parking'], ax = axs[1,2])

plt.tight_layout()

# %% [markdown]
# Exploratory Data Analytics
# Let's now spend some time doing what is arguably the most important step - understanding the data.
#
# If there is some obvious multicollinearity going on, this is the first place to catch it
# Here's where you'll also identify if some predictors directly have a strong association with the outcome variable
# Visualising Numeric Variables
# Let's make a pairplot of all the numeric variables

# %% [markdown]
# Let us do a box plot of all the variables

# %%
fig_dims = (20, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(ax=ax, data=housing)

#sns.boxplot(data=a, height=10, aspect=0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It can be observed that range of values for price is highly skewed when compared to the other variables. This provides a view that the variables need to be scaled/normalized.  Scaling does not impact the model. So it is  important to rescale the variables so that they have a comparable scale. Otherwise, coefficients  obtained by fitting the regression model might be very large or very small as compared to the other coefficients.  So it is advised to use standardization or normalization so that the units of the coefficients obtained are all on the same scale. As you know, there are two common ways of rescaling. There are several methods of scaing such as min max scaling, L2 normalization and standard scaling. The associated python libraries are.
#
# MinMaxScaler(), normalize() and StandardScaler() from sklearn.preprocessing library
#
#
# We shall do scaling later.

# %% [markdown]
# The difference in scale of the predicted variables is prominent

# %%
fig_dims = (20, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(ax=ax, data=housing)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Transform categorical Yes/No variables to binary variable

# %% [markdown]
# It can be observed that several predictor variables have the values as 'Yes' or 'No'.
#
# In order to fit a regression line, the categorical values need to be converted to numerical values. A 'Yes' is conveted to a 1 and a 'No' is conveted to a 0.

# %%
# List of variables to map 

varlist =  ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']

# Defining the map function
def binary_map(x):
    return x.map({'yes': 1, "no": 0})

# Applying the function to the housing list
housing[varlist] = housing[varlist].apply(binary_map)

# %%
housing
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea furnishingstatus
# 15   9100000  6000         4          1        2         1          0         1                0                0        2         0   semi-furnished
# 16   9100000  6600         4          2        2         1          1         1                0                1        1         1      unfurnished
# 17   8960000  8500         3          2        4         1          0         0                0                1        2         0        furnished
# 18   8890000  4600         3          2        2         1          1         0                0                1        2         0        furnished
# 19   8855000  6420         3          2        2         1          0         0                0                1        1         1   semi-furnished
# ...

# %% [markdown]
# Visualising Categorical Variables using the sns box plots. Plots of price versus the categorical variables

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'mainroad', y = 'price', data = housing)
plt.subplot(2,3,2)
sns.boxplot(x = 'guestroom', y = 'price', data = housing)
plt.subplot(2,3,3)
sns.boxplot(x = 'basement', y = 'price', data = housing)
plt.subplot(2,3,4)
sns.boxplot(x = 'hotwaterheating', y = 'price', data = housing)
plt.subplot(2,3,5)
sns.boxplot(x = 'airconditioning', y = 'price', data = housing)
plt.subplot(2,3,6)
sns.boxplot(x = 'furnishingstatus', y = 'price', data = housing)
plt.show()

# %% [markdown]
# We can observe three variables using the hue option. Visualizing the price with airconditionaing and furnishing type

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'furnishingstatus', y = 'price', hue = 'airconditioning', data = housing)
plt.show()

# %%
# Check the housing dataframe now

housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea furnishingstatus
# 15  9100000  6000         4          1        2         1          0         1                0                0        2         0   semi-furnished
# 16  9100000  6600         4          2        2         1          1         1                0                1        1         1      unfurnished
# 17  8960000  8500         3          2        4         1          0         0                0                1        2         0        furnished
# 18  8890000  4600         3          2        2         1          1         0                0                1        2         0        furnished
# 19  8855000  6420         3          2        2         1          0         0                0                1        1         1   semi-furnished

# %% [markdown]
# ## Converting a three level categorical variable to integers

# %% [markdown]
# #Dummy Variables
# The variable furnishingstatus has three levels. We need to convert these levels into integer as well.
#
# For this, we will use what is called dummy variables.

# %%
# Get the dummy variables for the feature 'furnishingstatus' and store it in a new variable - 'status'
status = pd.get_dummies(housing['furnishingstatus'])

# %%
# Check what the dataset 'status' looks like
status.head()
# Out:
#     furnished  semi-furnished  unfurnished
# 15          0               1            0
# 16          0               0            1
# 17          1               0            0
# 18          1               0            0
# 19          0               1            0

# %% [markdown]
# Now, you don't need three columns. You can drop the furnished column, as the type of furnishing can be identified with just the last two columns where —
#
# 00 will correspond to furnished
# 01 will correspond to unfurnished
# 10 will correspond to semi-furnished

# %%
# Let's drop the first column from status df using 'drop_first = True'

status = pd.get_dummies(housing['furnishingstatus'], drop_first = True)

# %% [markdown]
# Data Preparation
# You can see that your dataset has many columns with values as 'Yes' or 'No'.
#
# But in order to fit a regression line, we would need numerical values and not string. Hence, we need to convert them to 1s and 0s, where 1 is a 'Yes' and 0 is a 'No'.

# %%
# Add the results to the original housing dataframe

housing = pd.concat([housing, status], axis = 1)

# %%
# Now let's see the head of our dataframe.

housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea furnishingstatus  semi-furnished  unfurnished
# 15  9100000  6000         4          1        2         1          0         1                0                0        2         0   semi-furnished               1            0
# 16  9100000  6600         4          2        2         1          1         1                0                1        1         1      unfurnished               0            1
# 17  8960000  8500         3          2        4         1          0         0                0                1        2         0        furnished               0            0
# 18  8890000  4600         3          2        2         1          1         0                0                1        2         0        furnished               0            0
# ...

# %%
# Drop 'furnishingstatus' as we have created the dummies for it

housing.drop(['furnishingstatus'], axis = 1, inplace = True)

# %%
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  semi-furnished  unfurnished
# 15  9100000  6000         4          1        2         1          0         1                0                0        2         0               1            0
# 16  9100000  6600         4          2        2         1          1         1                0                1        1         1               0            1
# 17  8960000  8500         3          2        4         1          0         0                0                1        2         0               0            0
# 18  8890000  4600         3          2        2         1          1         0                0                1        2         0               0            0
# 19  8855000  6420         3          2        2         1          0         0                0                1        1         1               1            0

# %% [markdown]
# Splitting the Data into Training and Testing Sets¶

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(housing, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# An alternate option to creating train test split is use of iloc. An example is ...<br>
# x=a.iloc[:,0:4] <br>
# y=a.iloc[:,4]<br>
# X_train,X_test,y_train,y_test=model_selection.train_test_split(x,y,test_size=0.2)

# %%
df_train.head()
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  semi-furnished  unfurnished
# 148  5600000  6360         3          1        3         1          0         0                0                0        0         1               1            0
# 236  4620000  2870         2          1        2         1          1         1                0                0        0         1               1            0
# 356  3773000  2520         5          2        1         0          0         1                0                1        1         0               0            0
# 425  3360000  3185         2          1        1         1          0         1                0                0        2         0               0            0
# 516  2450000  3240         2          1        1         0          1         0                0                0        1         0               0            1

# %%
fig_dims = (20, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(ax=ax, data=df_train)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
# scaler = StandardScaler()

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking','price']
num_vars

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  hotwaterheating  airconditioning   parking  prefarea  semi-furnished  unfurnished
# 148  0.523810  0.526907       0.4        0.0  0.666667         1          0         0                0                0  0.000000         1               1            0
# 236  0.390476  0.114134       0.2        0.0  0.333333         1          1         1                0                0  0.000000         1               1            0
# 356  0.275238  0.072738       0.8        0.5  0.000000         0          0         1                0                1  0.333333         0               0            0
# 425  0.219048  0.151390       0.2        0.0  0.000000         1          0         1                0                0  0.666667         0               0            0
# ...

# %%
df_train.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories    mainroad   guestroom    basement  hotwaterheating  airconditioning     parking    prefarea  semi-furnished  unfurnished
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000       361.000000       361.000000  361.000000  361.000000      361.000000   361.000000
# mean     0.383701    0.350081    0.390582    0.127424    0.268698    0.875346    0.168975    0.349030         0.038781         0.313019    0.218837    0.207756        0.476454     0.304709
# std      0.209712    0.207184    0.149146    0.224465    0.287833    0.330784    0.375250    0.477325         0.193341         0.464366    0.287286    0.406264        0.500138     0.460923
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000         0.000000         0.000000    0.000000    0.000000        0.000000     0.000000
# ...

# %%
# df_train_iv = df_train.drop(['price', 'area'], axis=1)

fig_dims = (20, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(ax=ax, data=df_train)

#sns.boxplot(data=a, height=10, aspect=0.6)
# Out:
# <AxesSubplot:>

# %%
fig_dims = (20, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(ax=ax, data=df_train)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Violin plots provide the Kernel density estimate as well...

# %%
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  hotwaterheating  airconditioning   parking  prefarea  semi-furnished  unfurnished
# 148  0.523810  0.526907       0.4        0.0  0.666667         1          0         0                0                0  0.000000         1               1            0
# 236  0.390476  0.114134       0.2        0.0  0.333333         1          1         1                0                0  0.000000         1               1            0
# 356  0.275238  0.072738       0.8        0.5  0.000000         0          0         1                0                1  0.333333         0               0            0
# 425  0.219048  0.151390       0.2        0.0  0.000000         1          0         1                0                0  0.666667         0               0            0
# ...

# %%
df_train.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories    mainroad   guestroom    basement  hotwaterheating  airconditioning     parking    prefarea  semi-furnished  unfurnished
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000       361.000000       361.000000  361.000000  361.000000      361.000000   361.000000
# mean     0.383701    0.350081    0.390582    0.127424    0.268698    0.875346    0.168975    0.349030         0.038781         0.313019    0.218837    0.207756        0.476454     0.304709
# std      0.209712    0.207184    0.149146    0.224465    0.287833    0.330784    0.375250    0.477325         0.193341         0.464366    0.287286    0.406264        0.500138     0.460923
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000         0.000000         0.000000    0.000000    0.000000        0.000000     0.000000
# ...

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# As you might have noticed, area seems to the correlated to price the most. Let's see a pairplot for area vs price.
#
#
# Dividing into X and Y sets for the model building¶

# %% [markdown]
# # Model building

# %% [markdown]
# The popular techniques for linear regression models are:
#
# * **Simple Linear Regression**<br>
# This is a  statistical model built from statistical parameters such as means, standard deviations, correlations and covariance.
# * **Ordinary Least Squares**<br>
# The Ordinary Least Squares procedure seeks to minimize the sum of the squared residuals. This means that given a regression line through the data we calculate the distance from each data point to the regression line, square it, and sum all of the squared errors together. This is the quantity that ordinary least squares seeks to minimize.<br>This approach is a matrics formulation approach which use linear algebra operations to estimate the optimal values for the coefficients. <br>
# The linear algebra operations are not required to be carried out in implementation. It can be easily implemented using the ols function from statsmodel library. <br>
# * **Gradient Descent**
# This operation is called Gradient Descent and works by starting with random values for each coefficient. The sum of the squared errors are calculated for each pair of input and output values. A learning rate is used as a scale factor and the coefficients are updated in the direction towards minimizing the error. The process is repeated until a minimum sum squared error is achieved or no further improvement is possible.

# %% [markdown]
# ## Recursive Feature Elimination (RFE)

# %% [markdown]
# Recursive Feature Elimination, or RFE for short, is a popular feature selection algorithm.
#
# RFE is used for selecting those features/variables (columns) in a training dataset that are more or most relevant in predicting the target variable.
#
# LinearRegression function from SciKit is used for Linear regression

# %%
y_train = df_train.pop('price')
X_train = df_train

# %% [markdown]
# An alternative to the pop function is to use the iloc function to cull out y train predicted variable from the training dataset
#
# As an example<br>
# y_train =pd.iloc[:0]<br>
# X_train =pd.iloc[:,0:4]

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train.head(10)
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  hotwaterheating  airconditioning   parking  prefarea  semi-furnished  unfurnished
# 148  0.526907       0.4        0.0  0.666667         1          0         0                0                0  0.000000         1               1            0
# 236  0.114134       0.2        0.0  0.333333         1          1         1                0                0  0.000000         1               1            0
# 356  0.072738       0.8        0.5  0.000000         0          0         1                0                1  0.333333         0               0            0
# 425  0.151390       0.2        0.0  0.000000         1          0         1                0                0  0.666667         0               0            0
# 516  0.157895       0.2        0.0  0.000000         0          1         0                0                0  0.333333         0               0            1
# ...

# %%
X_train
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  hotwaterheating  airconditioning   parking  prefarea  semi-furnished  unfurnished
# 148  0.526907       0.4        0.0  0.666667         1          0         0                0                0  0.000000         1               1            0
# 236  0.114134       0.2        0.0  0.333333         1          1         1                0                0  0.000000         1               1            0
# 356  0.072738       0.8        0.5  0.000000         0          0         1                0                1  0.333333         0               0            0
# 425  0.151390       0.2        0.0  0.000000         1          0         1                0                0  0.666667         0               0            0
# 516  0.157895       0.2        0.0  0.000000         0          1         0                0                0  0.333333         0               0            1
# ...

# %%
print(lm)
# Out:
# LinearRegression()

# %%
# Recursive feature elimination# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
rfe = RFE(lm, n_features_to_select=6)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', True, 1),
#  ('bedrooms', False, 7),
#  ('bathrooms', True, 1),
#  ('stories', True, 1),
#  ('mainroad', False, 5),
#  ('guestroom', False, 6),
#  ('basement', False, 4),
#  ('hotwaterheating', False, 2),
#  ('airconditioning', True, 1),
#  ('parking', True, 1),
#  ('prefarea', True, 1),
#  ('semi-furnished', False, 8),
#  ('unfurnished', False, 3)]

# %%
col = X_train.columns
col
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea', 'semi-furnished', 'unfurnished'], dtype='object')

# %% [markdown]
# Building model using statsmodel, for the detailed statistics¶

# %% [markdown]
# ## Variable Inflation Factor(VIF)

# %% [markdown]
# Variance inflation factor (VIF) is a measure of the amount of multicollinearity in a set of multiple regression variables. Mathematically, the VIF for a regression model variable is equal to the ratio of the overall model variance to the variance of a model that includes only that single independent variable. This ratio is calculated for each independent variable. A high VIF indicates that the associated independent variable is highly collinear with the other variables in the model.

# %% [markdown]
# Detecting multicollinearity is important because while multicollinearity does not reduce the explanatory power of the model, it does reduce the statistical significance of the independent variables.

# %% [markdown]
# ### Test for collinearity

# %%
# Calculate the VIFs for the model
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
vif = pd.DataFrame()
X = X_train_rfe
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  7.40
# 4          mainroad  6.31
# 0              area  5.01
# 11   semi-furnished  2.79
# 3           stories  2.78
# 6          basement  2.03
# 12      unfurnished  1.98
# 9           parking  1.87
# 8   airconditioning  1.81
# 2         bathrooms  1.63
# 5         guestroom  1.51
# 10         prefarea  1.49
# 7   hotwaterheating  1.08

# %% [markdown]
# # Model evaluation and analysis of results

# %% [raw]
# ## Assumptions of Multiple Linear Regression
#
# Multiple linear regression analysis makes several key assumptions. The assumptions need to be validated.
#
# Assumption 1: There must be a linear relationship between the predicted variable and the independent variables. A good means of checking this is scatter plats. Scatterplots can show if there is a linear relationship or nonlinear relationship such as a curvilinear relationship.
#
# Assumption 2: Multivariate Normality–Multiple regression assumes that the residuals are normally distributed or near normal distribution with not much of skew and kurtosis. THis can be checked using scatter plots.
#
# Assumption 3: No Multicollinearity—Multiple regression assumes that the independent variables are not highly correlated with each other.  One way of checking correlation between independent variables is to plot the correlation between independent variables. Further if there are too many independent variables typically >10 or so and if they are correlated a suggested practice is to exclude the correlated variables and reduce the number of independent variables. There are several Dimensionality Reduction (DR) techniques to identify redundant variables such as Redundant Feature Elimination (RFE),Variance Inflation Factor (VIF) and Principal Component Analysis (PCA).
#
# Assumption 4: Homoscedasticity–This assumption states that the variance of error terms is similar across the values of the independent variables.  A plot of standardized residuals versus predicted values can show whether points are equally distributed across all values of the independent variables.
#
# Assumption 5: No Auto correlation - Linear regression analysis requires that there is little or no autocorrelation in the data. Autocorrelation occurs when the residuals are not independent from each other. In other words when the value of y(x+1) is not independent from the value of y(x). A common method of testing for autocorrelation is the Durbin-Watson test.
#
# ##  OLS (Ordinary Least Square) Regression Summary
#
# An intercept is not included by default and should be added by the user. This is realized by the add_constant function

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     49.95
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):           2.56e-71
# Time:                        15:07:22   Log-Likelihood:                 242.54
# No. Observations:                 361   AIC:                            -457.1
# Df Residuals:                     347   BIC:                            -402.6
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0851      0.031      2.766      0.006       0.025       0.146
# ...

# %% [markdown]
# ## Statistical inference from OLS summary
#
# **F Value, Prob(F) and Condition No**
#
# The "F value'' and "Prob(F)'' statistics test the overall significance of the regression model. Specifically, they test the null hypothesis that all of the regression coefficients are equal to zero. This tests the full model against a model with no variables and with the estimate of the dependent variable being the mean of the values of the dependent variable. The F value is the ratio of the mean regression sum of squares divided by the mean error sum of squares. Its value will range from zero to an arbitrarily large number.
#
# The value of Prob(F) is the probability that the null hypothesis for the full model is true (i.e., that all of the regression coefficients are zero). For example, if Prob(F) has a value of 0.01000 then there is 1 chance in 100 that all of the regression parameters are zero. This low a value would imply that at least some of the regression parameters are nonzero and that the regression equation does have some validity in fitting the data (i.e., the independent variables are not purely random with respect to the dependent variable). Lesser the better.
#
# Condition number of a function is a measure of how much the output value of the function can change for a small change in the input argument. This is used to measure how sensitive a function is to changes or errors in the input, and how much error in the output results from an error in the input. In linear regression the condition number of the moment matrix can be used as a diagnostic for multicollinearity.
#
# Skewness is a measure of the asymmetry of the probability distribution of a random variable about its mean. In other words, skewness tells you the amount and direction of skew (departure from horizontal symmetry)
#
# Kurtosis tells you the height and sharpness of the central peak, relative to that of a standard bell curve.

# %% [markdown]
# Detecting multicollinearity is important because while multicollinearity does not reduce the explanatory power of the model, it does reduce the statistical significance of the independent variables.

# %% [markdown]
# Residual Analysis of the train data
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_price = lm.predict(X_train_rfe)

# %%
res = (y_train_price - y_train)

# %%
# Importing the required libraries for plots.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Test for normal distribution of error terms

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20) # Plot heading   
plt.ylabel('', fontsize = 18)
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %%
plt.scatter(y_train,res)
plt.show()
# There may be some relation in the error terms.

# %% [markdown]
# Model Evaluation
#
# Applying the scaling on the test sets¶

# %%
num_vars = ['area','stories', 'bathrooms', 'airconditioning', 'prefarea','parking','price']

# %%
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])

# %% [markdown]
# Dividing into X_test and y_test¶

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
y_test
# Out:
# 244    0.375000
# 287    0.326923
# 166    0.480769
# 176    0.471154
# 282    0.336538
# 46     0.783654
# 402    0.230769
# 267    0.354808
# 217    0.413462
# 124    0.567308
# 449    0.182692
# 419    0.211538
# 394    0.230769
# 457    0.177885
# 481    0.153846
# 197    0.430769
# 44     0.788462
# 454    0.181731
# 531    0.056731
# 478    0.153846
# 133    0.548077
# 399    0.230769
# 256    0.365385
# 477    0.153846
# 530    0.057692
# 519    0.086538
# 123    0.567308
# 406    0.225962
# 372    0.250000
# 140    0.538462
# 130    0.555769
# 375    0.250000
# 164    0.490385
# 98     0.614423
# 411    0.221154
# 401    0.230769
# 18     0.971154
# 73     0.668269
# 408    0.221154
# 487    0.144231
# 110    0.586538
# 52     0.759615
# 21     0.942308
# 188    0.447115
# 427    0.207692
# 400    0.230769
# 469    0.163462
# 263    0.355769
# 458    0.177885
# 538    0.009615
# 181    0.466346
# 521    0.080769
# 252    0.370192
# 292    0.326923
# 520    0.086538
# ...

# %%
# Adding constant variable to test dataframe
X_test = sm.add_constant(X_test)

# %%
# Creating X_test_new dataframe by dropping variables from X_test
X_test_rfe = X_test[X_train_rfe.columns]

# %%
# Making predictions
y_pred = lm.predict(X_test_rfe)

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# 0.6550019795069824

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# ## Test for Heteroscadasticity

# %%
residual = y_test- y_pred
fig, ax = plt.subplots(figsize=(20,10))
ax.hlines(y=0, xmin=0, xmax=1, linewidth=5, color='r')

ax.scatter(y_pred, residual)
ax.axis(xmin=0,xmax=1)

fig.suptitle('Visualization of Residuals', fontsize = 40)              # Plot heading 
plt.xlabel('y_predict', fontsize = 40)                          # X-label
plt.ylabel('residual', fontsize = 40) 
plt.xticks(fontsize= 25)
plt.yticks(fontsize= 25)
plt.show()

# %%
# Visualizing the residuals
residual = y_test - y_pred
fig = plt.figure()
plt.scatter(y_pred, residual)
fig.suptitle('Visualization of Residuals', fontsize = 20)              # Plot heading 
plt.xlabel('y_predict', fontsize = 18)                          # X-label
plt.ylabel('residual', fontsize = 18)
# Out:
# Text(0, 0.5, 'residual')

# %% [markdown]
# ## The solution
# <br>
# The final equation of best fit is:
# <br>
# price=0.35×area+0.20×bathrooms+0.19×stories+0.10×airconditioning+0.10×parking+0.11×prefarea

# %% [markdown]
# # References
#
# 1. https://machinelearningmastery.com/linear-regression-for-machine-learning/
# 2. https://www.kaggle.com/ashydv/housing-dataset
# 3. https://pandas.pydata.org/pandas-docs/version/0.15/tutorials.html
# 4. https://jeffmacaluso.github.io/post/LinearRegressionAssumptions/
# 5. https://www.accelebrate.com/blog/interpreting-results-from-linear-regression-is-the-data-appropriate
